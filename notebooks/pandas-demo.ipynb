# %%
import pandas as pd

# %%
data = pd.read_csv("services.csv")
data.head()

# %%
data.info()
print(f"data dimension: {data.shape}")

# %%
exclude_col = "lang_code"
x = data.iloc[:, data.columns != exclude_col]

print(f"x dimension: {x.shape}")
x.head()

# %%
y = data.iloc[:,data.columns == exclude_col]
print(f"y dimension: {y.shape}")
y.head()
